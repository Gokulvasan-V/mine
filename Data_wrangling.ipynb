# %% [markdown]
# <a href="https://colab.research.google.com/github/GokulvasanV/mine/blob/main/Data_wrangling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data wrangling**

# %%
import pandas as pd

# %%
# import data directly from website
link="https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/titanic.csv"
data_set= pd.read_csv(link)
# showing 1st 5 data's
data_set.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %% [markdown]
# **creating our own Dataframe**

# %%
# here we created emty Dataframe
data_frame=pd.DataFrame()
# here we are adding colomns
data_frame['Names']=['Gokul','Naveen','Muthuraj']
data_frame['Ages']=[22,22,23]
data_frame['salary(in thousands)']=[30,25,15]
# printing our created Dataframe
data_frame
# Out:
#       Names  Ages  salary(in thousands)
# 0     Gokul    22                    30
# 1    Naveen    22                    25
# 2  Muthuraj    23                    15

# %%
# adding new row
new_row=pd.Series(['Mani',22,51],index=['Names','Ages','salary(in thousands)'])
data_frame.append(new_row,ignore_index=True)
# Out:
#       Names  Ages  salary(in thousands)
# 0     Gokul    22                    30
# 1    Naveen    22                    25
# 2  Muthuraj    23                    15
# 3      Mani    22                    51

# %% [markdown]
# # **Describing data**

# %%
data_set.head()
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
# seeing dimension of data
data_set.shape
# Out:
# (1313, 6)

# %%
# describe the data via statistics 
data_set.describe()
# Out:
#               Age     Survived      SexCode
# count  756.000000  1313.000000  1313.000000
# mean    30.397989     0.342727     0.351866
# std     14.259049     0.474802     0.477734
# min      0.170000     0.000000     0.000000
# 25%     21.000000     0.000000     0.000000
# 50%     28.000000     0.000000     0.000000
# 75%     39.000000     1.000000     1.000000
# max     71.000000     1.000000     1.000000

# %% [markdown]
# # **Navigating the Dataset**

# %%
#show 0th column
data_set.iloc[0]
# Out:
# Name        Allen, Miss Elisabeth Walton
# PClass                               1st
# Age                                 29.0
# Sex                               female
# Survived                               1
# SexCode                                1
# Name: 0, dtype: object

# %%
# show 1st four rows
data_set.iloc[:5]
# Out:
#                                             Name PClass    Age     Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  female
# 1                    Allison, Miss Helen Loraine    1st   2.00  female
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    male
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  female
# 4                  Allison, Master Hudson Trevor    1st   0.92    male
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %%
# show from 5th to 10th location data
data_set.iloc[5:11]
# Out:
#                                             Name PClass   Age     Sex  \
# 5                             Anderson, Mr Harry    1st  47.0    male
# 6               Andrews, Miss Kornelia Theodosia    1st  63.0  female
# 7                         Andrews, Mr Thomas, jr    1st  39.0    male
# 8   Appleton, Mrs Edward Dale (Charlotte Lamson)    1st  58.0  female
# 9                         Artagaveytia, Mr Ramon    1st  71.0    male
# 10                     Astor, Colonel John Jacob    1st  47.0    male
#
#     Survived  SexCode
# 5          1        0
# 6          1        1
# 7          0        0
# 8          1        1
# 9          0        0
# 10         0        0

# %%
data_set.set_index(data_set['Name'])
# show by person detials
data_set.loc["Appleton, Mrs Edward Dale (Charlotte Lamson)"]

# %% [markdown]
# ## **Selecting row based condition**

# %%
#data_set.reset_index(drop=True)
data_set[data_set['Sex']=='male']
# Out:
#                                      Name PClass    Age   Sex  Survived  \
# 2     Allison, Mr Hudson Joshua Creighton    1st  30.00  male         0
# 4           Allison, Master Hudson Trevor    1st   0.92  male         1
# 5                      Anderson, Mr Harry    1st  47.00  male         1
# 7                  Andrews, Mr Thomas, jr    1st  39.00  male         0
# 9                  Artagaveytia, Mr Ramon    1st  71.00  male         0
# ...                                   ...    ...    ...   ...       ...
# 1308                   Zakarian, Mr Artun    3rd  27.00  male         0
# 1309               Zakarian, Mr Maprieder    3rd  26.00  male         0
# 1310                     Zenni, Mr Philip    3rd  22.00  male         0
# 1311                     Lievens, Mr Rene    3rd  24.00  male         0
# 1312                       Zimmerman, Leo    3rd  29.00  male         0
#
#       SexCode
# 2           0
# 4           0
# 5           0
# 7           0
# 9           0
# ...

# %%
data_set[data_set['Sex']=='male']['Survived']
# Out:
# 2       0
# 4       1
# 5       1
# 7       0
# 9       0
#        ..
# 1308    0
# 1309    0
# 1310    0
# 1311    0
# 1312    0
# Name: Survived, Length: 851, dtype: int64

# %%
data_set[(data_set['Sex']=='male') & (data_set['Survived']==0)]
# Out:
#                                      Name PClass   Age   Sex  Survived  \
# 2     Allison, Mr Hudson Joshua Creighton    1st  30.0  male         0
# 7                  Andrews, Mr Thomas, jr    1st  39.0  male         0
# 9                  Artagaveytia, Mr Ramon    1st  71.0  male         0
# 10              Astor, Colonel John Jacob    1st  47.0  male         0
# 14                     Baumann, Mr John D    1st   NaN  male         0
# ...                                   ...    ...   ...   ...       ...
# 1308                   Zakarian, Mr Artun    3rd  27.0  male         0
# 1309               Zakarian, Mr Maprieder    3rd  26.0  male         0
# 1310                     Zenni, Mr Philip    3rd  22.0  male         0
# 1311                     Lievens, Mr Rene    3rd  24.0  male         0
# 1312                       Zimmerman, Leo    3rd  29.0  male         0
#
#       SexCode
# 2           0
# 7           0
# 9           0
# 10          0
# 14          0
# ...       ...
# ...

# %%
data_set[(data_set['Sex']=='male') & (data_set['Survived']==0) & (data_set['Age']==25)]
# Out:
#                                  Name PClass   Age   Sex  Survived  SexCode
# 21                 Birnbaum, Mr Jakob    1st  25.0  male         0        0
# 351    Bryhl, Mr Kurt Arnold Gottfrid    2nd  25.0  male         0        0
# 353        Butler, Mr Reginald Fenton    2nd  25.0  male         0        0
# 390               Denbury, Mr Herbert    2nd  25.0  male         0        0
# 483  Leyson, Mr Robert William Norman    2nd  25.0  male         0        0
# 561                  Sobey, Mr Hayden    2nd  25.0  male         0        0
# 563          Stokes, Mr Philip Joseph    2nd  25.0  male         0        0
# 619                   Ali, Mr William    3rd  25.0  male         0        0
# 636                  Arnold, Mr Josef    3rd  25.0  male         0        0
# 753             Dantchoff, Mr Khristo    3rd  25.0  male         0        0
# 764                 Delalic, Mr Regyo    3rd  25.0  male         0        0
# ...

# %% [markdown]
# ## **Replacing values**

# %%
data_set['Sex'].replace('female','Women')
# Out:
# 0       Women
# 1       Women
# 2        male
# 3       Women
# 4        male
#         ...
# 1308     male
# 1309     male
# 1310     male
# 1311     male
# 1312     male
# Name: Sex, Length: 1313, dtype: object

# %%
data_set['Sex'].replace(['male','female'],['Man','Women'],inplace=True) #inplace - using for replacing this modification into dataset

# %%
data_set.head(5)
# Out:
#                                             Name PClass    Age    Sex  \
# 0                   Allen, Miss Elisabeth Walton    1st  29.00  Women
# 1                    Allison, Miss Helen Loraine    1st   2.00  Women
# 2            Allison, Mr Hudson Joshua Creighton    1st  30.00    Man
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)    1st  25.00  Women
# 4                  Allison, Master Hudson Trevor    1st   0.92    Man
#
#    Survived  SexCode
# 0         1        1
# 1         0        1
# 2         0        0
# 3         0        1
# 4         1        0

# %% [markdown]
# ## **renaming columns**

# %%
data_set.rename(columns={'PClass':'Passenger Class'},inplace=True) # inplace change this modification in data set also

# %%
data_set.head()
# Out:
#                                             Name Passenger Class    Age  \
# 0                   Allen, Miss Elisabeth Walton             1st  29.00
# 1                    Allison, Miss Helen Loraine             1st   2.00
# 2            Allison, Mr Hudson Joshua Creighton             1st  30.00
# 3  Allison, Mrs Hudson JC (Bessie Waldo Daniels)             1st  25.00
# 4                  Allison, Master Hudson Trevor             1st   0.92
#
#      Sex  Survived  SexCode
# 0  Women         1        1
# 1  Women         0        1
# 2    Man         0        0
# 3  Women         0        1
# 4    Man         1        0

# %%
# show my columns in dict format
import collections
# create dictionary 
columns_name= collections.defaultdict(str)

for name in data_set.columns:
  columns_name[name]

columns_name
# Out:
# defaultdict(str,
#             {'Name': '',
#              'Passenger Class': '',
#              'Age': '',
#              'Sex': '',
#              'Survived': '',
#              'SexCode': ''})

# %% [markdown]
# ## **Finding the Minimum, Maximum, Sum, Average, Count**
